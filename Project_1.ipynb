# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# loading data

# %%
df1 = pd.read_csv("IT Salary Survey EU  2020.csv")
df2 = pd.read_csv("IT Salary Survey EU 2018.csv")
df3 = pd.read_csv("T Salary Survey EU 2019.csv")

# %% [markdown]
# merging the datasets

# %%
merged_df =pd.merge(df1,df2, on='Position')
df3.rename(columns={"Position (without seniority)": "Position"},inplace=True)
merged_df = pd.merge(merged_df,df3, on='Position')
merged_df.head()
# Out:
#            Timestamp_x  Age_x Gender_x  City_x           Position  \
# 0  24/11/2020 11:14:15   26.0     Male  Munich  Software Engineer
# 1  24/11/2020 11:14:15   26.0     Male  Munich  Software Engineer
# 2  24/11/2020 11:14:15   26.0     Male  Munich  Software Engineer
# 3  24/11/2020 11:14:15   26.0     Male  Munich  Software Engineer
# 4  24/11/2020 11:14:15   26.0     Male  Munich  Software Engineer
#
#   Total years of experience Years of experience in Germany Seniority level_x  \
# 0                         5                              3            Senior
# 1                         5                              3            Senior
# 2                         5                              3            Senior
# 3                         5                              3            Senior
# 4                         5                              3            Senior
#
#   Your main technology / programming language_x  \
# 0                                    TypeScript
# ...

# %% [markdown]
# Size of the data

# %%
merged_df.shape
# Out:
# (434725, 58)

# %% [markdown]
# Getting the info of the dataset

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 434725 entries, 0 to 434724
# Data columns (total 58 columns):
#  #   Column                                                                                                                   Non-Null Count   Dtype
# ---  ------                                                                                                                   --------------   -----
#  0   Timestamp_x                                                                                                              434725 non-null  object
#  1   Age_x                                                                                                                    424377 non-null  float64
#  2   Gender_x                                                                                                                 432156 non-null  object
# ...

# %% [markdown]
# There are several rows with no values

# %% [markdown]
# Know the datatypes

# %%
merged_df.dtypes
# Out:
# Timestamp_x                                                                                                                 object
# Age_x                                                                                                                      float64
# Gender_x                                                                                                                    object
# City_x                                                                                                                      object
# Position                                                                                                                    object
# Total years of experience                                                                                                   object
# Years of experience in Germany                                                                                              object
# ...

# %% [markdown]
# Descriptive statistics

# %%
merged_df.describe()
# Out:
#                Age_x  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  424377.000000                                       4.347250e+05
# mean       31.813918                                       6.512006e+06
# std         5.164082                                       8.025238e+08
# min        22.000000                                       1.000100e+04
# 25%        28.000000                                       5.700000e+04
# 50%        31.000000                                       6.800000e+04
# 75%        35.000000                                       8.000000e+04
# max        66.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                      301405.000000
# mean                                        65162.404525
# std                                         20880.952760
# ...

# %%
merged_df.duplicated().sum()
# Out:
# 2721

# %% [markdown]
# Removing duplicates

# %%
merged_df.drop_duplicates()
# Out:
#                 Timestamp_x  Age_x Gender_x     City_x           Position  \
# 0       24/11/2020 11:14:15   26.0     Male     Munich  Software Engineer
# 1       24/11/2020 11:14:15   26.0     Male     Munich  Software Engineer
# 2       24/11/2020 11:14:15   26.0     Male     Munich  Software Engineer
# 3       24/11/2020 11:14:15   26.0     Male     Munich  Software Engineer
# 4       24/11/2020 11:14:15   26.0     Male     Munich  Software Engineer
# ...                     ...    ...      ...        ...                ...
# 434720  25/11/2020 20:41:13   43.0     Male  Stuttgart     SAP Consultant
# 434721  25/11/2020 20:41:13   43.0     Male  Stuttgart     SAP Consultant
# 434722  25/11/2020 20:41:13   43.0     Male  Stuttgart     SAP Consultant
# 434723  25/11/2020 20:41:13   43.0     Male  Stuttgart     SAP Consultant
# 434724  25/11/2020 20:41:13   43.0     Male  Stuttgart     SAP Consultant
#
#        Total years of experience Years of experience in Germany  \
# ...

# %% [markdown]
# Rows with null values

# %% [markdown]
# Filtering data

# %%
merged_df[merged_df.Gender_x == 'Female']
# Out:
#                 Timestamp_x  Age_x Gender_x  City_x           Position  \
# 2639    24/11/2020 11:30:38   33.0   Female  Berlin  Software Engineer
# 2640    24/11/2020 11:30:38   33.0   Female  Berlin  Software Engineer
# 2641    24/11/2020 11:30:38   33.0   Female  Berlin  Software Engineer
# 2642    24/11/2020 11:30:38   33.0   Female  Berlin  Software Engineer
# 2643    24/11/2020 11:30:38   33.0   Female  Berlin  Software Engineer
# ...                     ...    ...      ...     ...                ...
# 434394  25/11/2020 17:46:23   34.0   Female  Berlin                NaN
# 434395  25/11/2020 17:46:23   34.0   Female  Berlin                NaN
# 434396  25/11/2020 17:46:23   34.0   Female  Berlin                NaN
# 434397  25/11/2020 17:46:23   34.0   Female  Berlin                NaN
# 434398  25/11/2020 17:46:23   34.0   Female  Berlin                NaN
#
#        Total years of experience Years of experience in Germany  \
# ...
